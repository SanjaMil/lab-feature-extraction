# %% [markdown]
# # Lab | Feature extraction

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'C:\Users\31645\OneDrive\Documents\Ironhack\LABs\lab-cleaning-categorical-data\files_for_lab\we_fn_use_c_marketing_customer_value_analysis.csv')

# %%
data
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %% [markdown]
# **Cleaning Data**

# %%
data.columns = [data.columns[i].replace(' ','_') for i in range(len(data.columns))]

# %%
data = data.rename(columns = {'Customer':'ID'})
data = data.set_index('ID')

# %%
import warnings
warnings.filterwarnings('ignore')
data_cat = data.select_dtypes(np.object)
data_num = data.select_dtypes(np.object)
#data_num
data_cat
# Out:
#               State Response  Coverage Education Effective_To_Date  \
# ID
# BU79786  Washington       No     Basic  Bachelor           2/24/11
# QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# AI49188      Nevada       No   Premium  Bachelor           2/19/11
# WW63253  California       No     Basic  Bachelor           1/20/11
# HB64268  Washington       No     Basic  Bachelor            2/3/11
# ...             ...      ...       ...       ...               ...
# LA72316  California       No     Basic  Bachelor           2/10/11
# PK87824  California      Yes  Extended   College           2/12/11
# TD14365  California       No  Extended  Bachelor            2/6/11
# UP19263  California       No  Extended   College            2/3/11
# Y167826  California       No  Extended   College           2/14/11
#
#         EmploymentStatus Gender Location_Code Marital_Status     Policy_Type  \
# ID
# ...

# %% [markdown]
# **Plot all the categorical variables with the proper plot. What can you see?**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
new_data = data_cat.groupby('State')
names = list(data_cat['State'].unique())
values = list(data_cat['State'].value_counts())

fig, axs = plt.subplots(1, 3, figsize=(15, 3), sharey=True) # 
axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)
#fig.suptitle('Categorical Plotting')

# %%
new_data1 = data_cat.groupby('Gender')
names = list(data_cat['Gender'].unique())
values = list(data_cat['Gender'].value_counts())

figure, axis = plt.subplots(1,2, figsize = (15,4), sharey = True)
axis[0].bar(names, values)
axis[1].scatter(names, values)

# %%
new_data1 = data_cat.groupby('EmploymentStatus')
names = list(data_cat['EmploymentStatus'].unique())
values = list(data_cat['EmploymentStatus'].value_counts())

figure, axis = plt.subplots(1,2, figsize = (15,4), sharey = True)
axis[0].bar(names, values)
axis[1].scatter(names, values)

# %% [markdown]
# **There might be some columns that seem to be redundant, check their values to be sure. What should we do with them?**

# %%
for i in data_cat.columns:
    new_data = data_cat.groupby(i)
    names = list(data_cat[i].unique())
    values = list(data_cat[i].value_counts())
    print(i)

    fig, axs = plt.subplots(1, 3, figsize=(15, 3), sharey=True) # 
    axs[0].bar(names, values)
    axs[1].scatter(names, values)
    axs[2].plot(names, values)

fig.suptitle('Categorical Plotting')
# Out:
# State
# Response
# Coverage
# Education
# Effective_To_Date
# EmploymentStatus
# Gender
# Location_Code
# Marital_Status
# Policy_Type
# Policy
# Renew_Offer_Type
# Sales_Channel
# Vehicle_Class
# Vehicle_Size
# Text(0.5, 0.98, 'Categorical Plotting')

# %%
import matplotlib.dates as dt
from datetime import datetime

# %%
D = list(data_cat['Effective_To_Date'].astype('int'))
x_values = []
for i in D:
    x_values.append(datetime(i))

x_values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_292/1005319037.py in <module>
# ----> 1 D = list(data_cat['Effective_To_Date'].astype('int'))
#       2 x_values = []
#       3 for i in D:
#       4     x_values.append(datetime(i))
#       5
#
# c:\users\31645\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# c:\users\31645\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
# ...
